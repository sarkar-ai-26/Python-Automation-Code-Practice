# %% [markdown]
# #### List indexing

# %%
L = [1,2,3,4,5,6]
print(L[0])
# Out:
# 1

# %%
print(len(L))
# Out:
# 6

# %%
print(L[3])
# Out:
# 4

# %%
#Negative Indexing
print(L[-1])
# Out:
# 6

# %% [markdown]
# #### List Slicing

# %%
print(L[1:3])
# Out:
# [2, 3]

# %%
Lista = ["a","b","c","d","e"]
Listb = [1,2,3,4,5]
Paired_list = [[I,j] for I in Lista for j in Listb]
Paired_list
# Out:
# [['a', 1],
#  ['a', 2],
#  ['a', 3],
#  ['a', 4],
#  ['a', 5],
#  ['b', 1],
#  ['b', 2],
#  ['b', 3],
#  ['b', 4],
#  ['b', 5],
#  ['c', 1],
#  ['c', 2],
#  ['c', 3],
#  ['c', 4],
#  ['c', 5],
#  ['d', 1],
#  ['d', 2],
#  ['d', 3],
#  ['d', 4],
#  ['d', 5],
#  ['e', 1],
#  ['e', 2],
#  ['e', 3],
#  ['e', 4],
#  ['e', 5]]

# %%
Nested_dict = {"Data_1": {"Name" : "Yash", "Job" : "IT"},
                "Data_2" : {"Name" : "Raj", "Job" : "IT"},
                "Data_3" : {"Name" : "Vikas", "Job" : "IT"} }
for key, value in Nested_dict.items():
	print(f"Outer Key : {key}, Outer Value: {value}")
	for key_, value_ in value.items():
		print(f"Outer Key : {key_}, Outer Value: {value_}")
# Out:
# Outer Key : Data_1, Outer Value: {'Name': 'Yash', 'Job': 'IT'}
# Outer Key : Name, Outer Value: Yash
# Outer Key : Job, Outer Value: IT
# Outer Key : Data_2, Outer Value: {'Name': 'Raj', 'Job': 'IT'}
# Outer Key : Name, Outer Value: Raj
# Outer Key : Job, Outer Value: IT
# Outer Key : Data_3, Outer Value: {'Name': 'Vikas', 'Job': 'IT'}
# Outer Key : Name, Outer Value: Vikas
# Outer Key : Job, Outer Value: IT

# %%
Dict_comp = {x:x**2 for x in range(15)}

# %%
Dict_comp
# Out:
# {0: 0,
#  1: 1,
#  2: 4,
#  3: 9,
#  4: 16,
#  5: 25,
#  6: 36,
#  7: 49,
#  8: 64,
#  9: 81,
#  10: 100,
#  11: 121,
#  12: 144,
#  13: 169,
#  14: 196}

# %% [markdown]
# ### Lambda function

# %%
var = lambda x:x**2

# %%
type(var)
# Out:
# function

# %%
var(5)
# Out:
# 25

# %%
sum = lambda x,y : x+y

# %%
sum(2,5)
# Out:
# 7

# %% [markdown]
# #### Map function map()

# %%
lists = [1,2,3,4,5]
print(list(map(lambda x:x**2,lists)))
# print(nlist)
# Out:
# [1, 4, 9, 16, 25]

# %%
li1 = [1,2,3]
li2 = [4,6,8]

print(list(map(lambda x,y:x+y,li1,li2)))
# Out:
# [5, 8, 11]

# %%
# map() to convert all strings values items in an iterable into a integer

print(list(map(int,['1','2','5','7'])))
# Out:
# [1, 2, 5, 7]

# %%
#convert all names in uppercase

names = ["yash","rohan","vikas"]
print(list(map(str.upper,names)))
# Out:
# ['YASH', 'ROHAN', 'VIKAS']

# %%
#Retrieve values inside a dictionary using map()

employess = [{"name":"yash","age":26},
             {"name":"raj","age":29}
             ]

def agefinder(listitem):
    return listitem["age"]

print(list(map(agefinder,employess)))
# Out:
# [26, 29]

# %% [markdown]
# ### Filter function

# %%
#retrieve only items which are even

def even(n):
    return n%2==0

# %%
li = [1,2,3,4,5,6,7,8]
print(list(filter(even,li)))
# Out:
# [2, 4, 6, 8]

# %%
#retrieve only items which are even using lambda function
li = [1,2,3,4,5,6,7,8]
even_ = lambda x:x%2==0

print(list(filter(even_,li)))
# Out:
# [2, 4, 6, 8]

# %%
# retrieve the values greater that 5

li = [1,2,3,4,5,6,7,8]
greater_5 = lambda x:x>5

print(list(filter(greater_5,li)))
# Out:
# [6, 7, 8]

# %%
# retrieve the values greater that 5 and even

li = [1,2,3,4,5,6,7,8]
greater_even = lambda x:x>5 and x%2==0
print(list(filter(greater_even,li)))
# Out:
# [6, 8]

# %%
#Retrieve values inside a dictionary using filter()

employess = [{"name":"yash","age":24},
             {"name":"raj","age":29}
             ]

def agecheck(item):
    return item["age"] > 25

print(list(filter(agecheck,employess)))
# Out:
# [{'name': 'raj', 'age': 29}]

# %% [markdown]
# ### File Handling

# %%
# Read the content of text file from the system
fp = r"C:\Users\yashr\PycharmProjects\Python-Automation-Code-Practice\assets\test"
with open(fp,"r") as f:
    v = f.read()
print(v)
# Out:
# The map() function is a higher-order function used in many programming languages (like Python and JavaScript) to transform data by applying a specific operation to every item in a collection (like a list or array).
# It essentially takes an input, runs it through a "machine" (your function), and gives you a new output without changing the original data.

# %%
with open(fp,"w+") as f:
    f.write(" Hello, overwriting the content")
with open(fp,"r") as f:
    nw = f.read()
print(nw)
# Out:
#  Hello, overwriting the content

# %%
with open(fp,"a+") as af:
    af.write("\n Appended content")

# %%
# write the content into file line by line

lines = ["line1\n","line2\n","line3\n"]

with open(fp,"w") as f:
    f.writelines(lines)

# %%
# reading total lines, total words. total characters from a file ->> readlines()

fp = r"C:\Users\yashr\PycharmProjects\Python-Automation-Code-Practice\assets\test"

def count_lines(fp):
    with open(fp,"r") as f:
        lines = f.readlines()

        print(f"Lines count : {len(lines)}")
        totalwords = sum(len(line.split()) for line in lines)
        print(f"Word count : {totalwords}")
        totalchars = sum(len(line) for line in lines)
        print(f"Total Characters : {totalchars}")

count_lines(fp)
# Out:
# Lines count : 3
# Word count : 3
# Total Characters : 18

# %%
# Write a content in a file then read the content form sam efile

with open(fp,"w+") as f:
    f.write("hello boss")
    d=f.seek(0)
    content = f.read()
print(content)
# Out:
# hello boss

# %% [markdown]
# #### OS Library

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\yashr\PycharmProjects\Python-Automation-Code-Practice\PythonPractice

# %%
newpath = "testfolder"
os.mkdir(newpath)

# %%
dir_list = os.listdir(cwd)
print(dir_list)
# Out:
# ['CodingPractice.ipynb', 'LeetCode.ipynb', 'LeetCode_Practice.ipynb', 'PythonLearning.ipynb', 'regx.ipynb', 'testfolder']

# %%
newdir = "newNew"
os.path.join(os.getcwd(),newdir)
# os.path.join(cwd,newdir)
# Out:
# 'C:\\Users\\yashr\\PycharmProjects\\Python-Automation-Code-Practice\\PythonPractice\\newNew'

# %%
if os.path.exists(cwd):
    print("true")
else:
    print("False")
# Out:
# true

# %% [markdown]
# #### Standard libs

# %% [markdown]
# ### random

# %%
 import random

 print(random.randint(1,10))
# Out:
# 9

# %%
print(random.choice([1,2,3,5,6]))
# Out:
# 5

# %%
print(random.choice(["a","d"]))
# Out:
# a

# %% [markdown]
# ### csv

# %%
import csv
with open("data.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['name','age','contact'])
    writer.writerow(['yash','27','2544585'])

# %%
with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'contact']
# ['yash', '27', '2544585']

# %% [markdown]
# ### datatime

# %%
from datetime import datetime,timedelta

ct = datetime.now()
print(ct)
# Out:
# 2026-04-08 19:58:21.840332

# %%
print(ct - timedelta(days=1))
# Out:
# 2026-04-07 19:58:21.840332

# %% [markdown]
# ### shutil

# %%
import shutil

shutil.copyfile("../PythonPractice/data.txt", 'data2.txt')
# Out:
# 'data2.txt'

# %% [markdown]
# ### json

# %%
# to convert the json string format data we can convert it in dictionary format for serialising the data.

# %%
import json

data = {"name":"yash","age":24}

str_data = json.dumps(data)
jsondict_data = json.loads(str_data)

print(str_data,"\n", jsondict_data)
# Out:
# {"name": "yash", "age": 24}
#  {'name': 'yash', 'age': 24}

# %% [markdown]
# ### Regular Expresssion

# %%
import re

text = "The map() function is a higher-order function used in many programming 98547 languages (like Python and 25478 JavaScript) to transform data by applying a specific operation to every item in a collection (like a list or array). "

# %%
pattern = r'\d+'
ma = re.search(pattern,text)
print(ma.group())
# Out:
# 98547

# %% [markdown]
# ### Exception Handling

# %%
den = int(input("Enter the denominotor : "))

result = 1/den
print(result)
# Out:
# 0.3333333333333333

# %%
deno = input("Enter the denominotor : ")

try: #this block can throw error
    result = 1/deno
    print(result)
    a=c
    devide = 5/deno
except ZeroDivisionError as e: #represent the error
    print("Deno should not be Zero, Enter Deno other thar Zero",e)
except NameError as r:
    print(r)
except TypeError as er:
    print(er)
# Out:
# unsupported operand type(s) for /: 'int' and 'str'

# %%
deno = int(input("Enter the denominotor : "))

try: #this block can throw error
    result = 1/deno
except ZeroDivisionError as e: #represent the error
    print("Deno should not be Zero, Enter Deno other thar Zero",e)
except NameError as r:
    print(r)
except TypeError as er:
    print(er)
else:
    print(result)
# Out:
# 0.25
