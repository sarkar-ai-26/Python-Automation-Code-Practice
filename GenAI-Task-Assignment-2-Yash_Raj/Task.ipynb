# %% [markdown]
# ![image.png](attachment:9f05070d-9b2e-4da1-8c49-0eb07efd2609.png)

# %% [markdown]
# ### Task 1 : Discount Rules (if /elif / else)
# ![image.png](attachment:95d985df-da18-45a9-830e-26bf3b98e7ed.png)

# %%
order_amount = input("Enter the order amount : ")

if order_amount.isdigit():
    order_amount = int(order_amount)
    if order_amount >= 2000:
        finalAmount = order_amount - (order_amount * (15/100))
    elif order_amount >= 1500 and order_amount < 2000:
        finalAmount = order_amount - (order_amount * (10/100))
    elif order_amount >= 1000 and order_amount <=1500:
        finalAmount = order_amount - (order_amount * (7/100))
    else:
        finalAmount = order_amount
        print(f"Discount is Zero")

    amount_after_tax = finalAmount + (finalAmount * (5/100))
    print(f"Order Amount : {order_amount}\n"
          f"Sub Total Amount after discount : {finalAmount}\n"
          f"Tax on discount : {(finalAmount * (5/100))}\n"
          f"Final Total Amount after Tax : {amount_after_tax}")

else:
    print("Invalid type")
# Out:
# Order Amount : 2000
# Sub Total Amount after discount : 1700.0
# Tax on discount : 85.0
# Final Total Amount after Tax : 1785.0

# %% [markdown]
# ### Task 2 : Process Multiple Orders (for Loop)
# ![image.png](attachment:20216a5d-5e35-4697-9ea5-0e72665c8a0a.png)

# %%
orders = [1200,2500,800,1750,3000]
ordersDiscount_count = 0
revenueAfterDiscount = 0
for order_amount in orders:
    if order_amount >= 2000:
        finalAmount = order_amount - (order_amount * (15/100))
        ordersDiscount_count +=1

    elif order_amount >= 1500 and order_amount < 2000:
        finalAmount = order_amount - (order_amount * (10/100))
        ordersDiscount_count +=1
    elif order_amount >= 1000 and order_amount <=1500:
        finalAmount = order_amount - (order_amount * (7/100))
        ordersDiscount_count +=1
    else:
        finalAmount = order_amount
        print(f"Discount is Zero")

    amount_after_tax = finalAmount + (finalAmount * (5/100))
    revenueAfterDiscount +=amount_after_tax
    print(f"Order Amount : {order_amount} -> "
           f"Discount % {((order_amount-finalAmount)/order_amount)*100} -> "
          f"Final Total Amount after Tax 5%: {amount_after_tax}\n")
print(f"Revenue after discount : {revenueAfterDiscount}")
print(f"Numbers of orders that recieved discount : {ordersDiscount_count}")
# Out:
# Order Amount : 1200 -> Discount % 7.000000000000001 -> Final Total Amount after Tax 5%: 1171.8
#
# Order Amount : 2500 -> Discount % 15.0 -> Final Total Amount after Tax 5%: 2231.25
#
# Discount is Zero
# Order Amount : 800 -> Discount % 0.0 -> Final Total Amount after Tax 5%: 840.0
#
# Order Amount : 1750 -> Discount % 10.0 -> Final Total Amount after Tax 5%: 1653.75
#
# Order Amount : 3000 -> Discount % 15.0 -> Final Total Amount after Tax 5%: 2677.5
#
# Revenue after discount : 8574.3
# Numbers of orders that recieved discount : 4

# %% [markdown]
# ### Task 3: User Menu (while loop + break/continue)
# ![image.png](attachment:16682832-61a4-48c2-bf01-51ff7d9a4483.png)

# %%
order_list = []

while True:
    menu_input = input(f"Menu:\n"
          f"1. Add order amount: \n"
          f"2. Show all orders and total after discounts \n"
          f"q. Quit \n"
          f"Selct Options from Menu (1/2/q)")

    if menu_input == "1":
        order = int(input("Add order amount: "))
        order_list.append(order)
    elif menu_input == "2":
        for order_amount in order_list:
            if order_amount >= 2000:
                finalAmount = order_amount - (order_amount * (15/100))
                ordersDiscount_count +=1

            elif order_amount >= 1500 and order_amount < 2000:
                finalAmount = order_amount - (order_amount * (10/100))
                ordersDiscount_count +=1
            elif order_amount >= 1000 and order_amount <=1500:
                finalAmount = order_amount - (order_amount * (7/100))
                ordersDiscount_count +=1
            else:
                finalAmount = order_amount
                print(f"Discount is Zero")

            amount_after_tax = finalAmount + (finalAmount * (5/100))
            revenueAfterDiscount +=amount_after_tax
            print(f"Order Amount : {order_amount} -> "
                   f"Discount % {((order_amount-finalAmount)/order_amount)*100} -> "
                  f"Final Total Amount after Tax 5%: {amount_after_tax}\n")
    elif menu_input == "q":
        break
    else:
        continue
# Out:
# Order Amount : 2525 -> Discount % 15.0 -> Final Total Amount after Tax 5%: 2253.5625
#
# Order Amount : 1456 -> Discount % 7.000000000000004 -> Final Total Amount after Tax 5%: 1421.7839999999999

# %% [markdown]
# ### Task 5 : Loop Control with Conditions (break & Continue)
# ![image.png](attachment:aeaefa86-6425-4b41-8c66-ca03b0b7f063.png)

# %%
daily =  [200,150,0,400,-1,300]
total_sales = 0
for item in daily:
    if item == -1:
        print("Data corrupted, Stopping execution")
        break
    elif item == 0:
        print(f"Sales are 0 today, No sales")
        continue
    else:
        total_sales +=item

print(f"Total Sales : {total_sales}")
# Out:
# Sales are 0 today, No sales
# Data corrupted, Stopping execution
# Total Sales : 750
