# %%
'''Greeting Bot: Create a variable for a user's name and "Last Login Date," then print a welcome message using an f-string.'''

un = "Yash"
last_login_date = "12/2/2026"

print(f"Welcome: {un}, Last Login : {last_login_date}")
# Out:
# Welcome: Yash, Last Login : 12/2/2026

# %%
'''Type Checker: Write a script that takes input and tells you if it's a string, integer, or float.'''

# %%
def typecheckerr():
    data =input("Enter your data: ")
    val = int(data)
    if data.isdigit():
        print("Integer")
    if "." in val:
        print("Float")
    else:
        print("String")

typecheckerr()
# Out:
# Integer
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       8     else:
#       9         print("String")
# ---> 11 typecheckerr()
#
# Cell In[16], line 6, in typecheckerr()
#       4 if data.isdigit():
#       5     print("Integer")
# ----> 6 if "." in val:
#       7     print("Float")
#       8 else:
#
# TypeError: argument of type 'int' is not a container or iterable
